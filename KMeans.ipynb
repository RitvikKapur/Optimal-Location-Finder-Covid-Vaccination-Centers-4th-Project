# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install opencage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencage
#   Downloading opencage-2.0.0-py3-none-any.whl (13 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.1.2-py3-none-any.whl (14 kB)
# Collecting pyopenssl>=0.15.1
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.6 MB/s
# Requirement already satisfied: Requests>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from opencage) (2.23.0)
# Collecting cryptography>=35.0
#   Downloading cryptography-37.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 11.5 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=35.0->pyopenssl>=0.15.1->opencage) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=35.0->pyopenssl>=0.15.1->opencage) (2.21)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from Requests>=2.2.0->opencage) (2.10)
# Installing collected packages: cryptography, pyopenssl, backoff, opencage
# Successfully installed backoff-2.1.2 cryptography-37.0.2 opencage-2.0.0 pyopenssl-22.0.0

# %%
pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.21.6)

# %%
import pandas as pd
from opencage.geocoder import OpenCageGeocode
import folium
from folium.plugins import FastMarkerCluster
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

# %%
# Load the dataset into a pandas dataframe.
df = pd.read_csv("/content/gdrive/MyDrive/COVIDcomp.csv", delimiter=',')
df_new=df
# Report the number of sentences.
print('Number of enteries: {:,}\n'.format(df_new.shape[0]))

# Display 10 random rows from the data.
df_new.head()
# Out:
# Number of enteries: 463
#    S.NO                           Institution      District  COVID BEDS Total  \
# 0     1                          A.S Hospital      Ariyalur                30
# 1     2                       Golden Hospital      Ariyalur                31
# 2     3                   Annai Arul Hospital  Chengalpattu                40
# 3     4  Chennai Emergency care Centre Pammal  Chengalpattu                16
# 4     5                    Dr. Rela Institute  Chengalpattu               160
#
#    COVID BEDS Occupied  latitudes  longitudes
# 0                   29  11.112990   79.075330
# 1                   30  11.141042   79.075387
# 2                   40  12.921027   80.088149
# 3                   16  12.973690   80.131118
# 4                  160  12.956058   80.141067

# %%
def nans(df): return df[df.isnull().any(axis=1)]

# %%
nans(df_new)
# Out:
# Empty DataFrame
# Columns: [S.NO, Institution, District, COVID BEDS Total, COVID BEDS Occupied, latitudes, longitudes]
# Index: []

# %%
dfn=df_new
covidsum=dfn['COVID BEDS Occupied'].sum()
avg=covidsum/463

# %%
print(covidsum) #Total Covid Cases
print(avg) #Average no. of cases per hospital
# Out:
# 21722
# 46.915766738660906

# %%
lat=dfn['latitudes'].to_list()
lon=dfn['longitudes'].to_list()

# %%
m = folium.Map([11.41644605351662,78.73045144938763],tiles='OpenStreetMap',zoom_start=6)
locations = list(zip(dfn.latitudes, dfn.longitudes))
folium.plugins.MarkerCluster(locations=locations,                     
               popups=dfn['Institution'].tolist()).add_to(m)  
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_d749dbdb356e9e447d6591912177619c {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_d749dbdb356e9e447d6591912177619c&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_d749dbdb356e9e447d6591912177619c = L.map(
#         &#x27;map_d749dbdb356e9e447d6591912177619c&#x27;, {
#         center: [11.41644605351662, 78.73045144938763],
#         zoom: 6,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_615e9f3565a2b182c05cad58adabec76 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_d749dbdb356e9e447d6591912177619c);
#
#             var marker_cluster_91b70de72bf133f09d714a3fd06a1e83 = L.markerClusterGroup({});
#             map_d749dbdb356e9e447d6591912177619c.addLayer(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#         var marker_4231a70c6f1d8f72ed9908f6ad0f254b = L.marker(
#             [11.11299012, 79.07532963],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#             var popup_0cea8f0d894b2e4b521035c3c1ffc5fe = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_f4fe5856016091d562f016480abe6c21 = $(`&lt;div id=&quot;html_f4fe5856016091d562f016480abe6c21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A.S Hospital&lt;/div&gt;`)[0];
#                 popup_0cea8f0d894b2e4b521035c3c1ffc5fe.setContent(html_f4fe5856016091d562f016480abe6c21);
#
#
#             marker_4231a70c6f1d8f72ed9908f6ad0f254b.bindPopup(popup_0cea8f0d894b2e4b521035c3c1ffc5fe)
#             ;
#
#
#
#
#         var marker_29b3fd36d5ec46b97231ef36fbfa0776 = L.marker(
#             [11.14104173, 79.0753868],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#             var popup_f9d8a45f1b7a9b3e4cb2360e3b79ffe5 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_57b027812f50045fd6dc8cea17d9a72f = $(`&lt;div id=&quot;html_57b027812f50045fd6dc8cea17d9a72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Hospital&lt;/div&gt;`)[0];
#                 popup_f9d8a45f1b7a9b3e4cb2360e3b79ffe5.setContent(html_57b027812f50045fd6dc8cea17d9a72f);
#
#
#             marker_29b3fd36d5ec46b97231ef36fbfa0776.bindPopup(popup_f9d8a45f1b7a9b3e4cb2360e3b79ffe5)
#             ;
#
#
#
#
#         var marker_4f09f00198716fab90d6c66a06a816a3 = L.marker(
#             [12.92102699, 80.08814903],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#             var popup_785d8c64435c7554e4afbcab8e84c4b4 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_55943df4915c8b21cfc228b0f3a8330a = $(`&lt;div id=&quot;html_55943df4915c8b21cfc228b0f3a8330a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Annai Arul Hospital&lt;/div&gt;`)[0];
#                 popup_785d8c64435c7554e4afbcab8e84c4b4.setContent(html_55943df4915c8b21cfc228b0f3a8330a);
#
#
#             marker_4f09f00198716fab90d6c66a06a816a3.bindPopup(popup_785d8c64435c7554e4afbcab8e84c4b4)
#             ;
#
#
#
#
#         var marker_aef85c41b45b696284d89c65cea7b131 = L.marker(
#             [12.97369039, 80.13111752],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#             var popup_32f8a1f60c4e0f763e8a785aba7bd515 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_4bba36e4c3844465269fe17a8ca40461 = $(`&lt;div id=&quot;html_4bba36e4c3844465269fe17a8ca40461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chennai Emergency care Centre Pammal&lt;/div&gt;`)[0];
#                 popup_32f8a1f60c4e0f763e8a785aba7bd515.setContent(html_4bba36e4c3844465269fe17a8ca40461);
#
#
#             marker_aef85c41b45b696284d89c65cea7b131.bindPopup(popup_32f8a1f60c4e0f763e8a785aba7bd515)
#             ;
#
#
#
#
#         var marker_8379de18605b44e1044e3f2013903073 = L.marker(
#             [12.9560584, 80.14106725],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_91b70de72bf133f09d714a3fd06a1e83);
#
#
#             var popup_2f1279852c3dd0828d14408325c1f349 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_79b10

# %%
m= folium.Map(
    location=[11.41644605351662, 78.73045144938763],
    zoom_start=7.5,tiles='OpenStreetMap')
folium.LayerControl().add_to(m)

for row in dfn.iterrows():
    row=row[1]
    folium.CircleMarker(location=(row["latitudes"],
                                  row["longitudes"]),
                        radius= row['COVID BEDS Occupied']/avg,
                        color="#FF0000",
                        popup=row['Institution'],
                        fill=True).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_cdfe16d731c8139875acf692e4124aa0 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_cdfe16d731c8139875acf692e4124aa0&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_cdfe16d731c8139875acf692e4124aa0 = L.map(
#         &#x27;map_cdfe16d731c8139875acf692e4124aa0&#x27;, {
#         center: [11.41644605351662, 78.73045144938763],
#         zoom: 7.5,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_887112aad9bdca820a96b986f1e67ffd = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_cdfe16d731c8139875acf692e4124aa0);
#
#             var layer_control_9ba5390a7937d21f5c68cff6d4990052 = {
#                 base_layers : { &quot;openstreetmap&quot; : tile_layer_887112aad9bdca820a96b986f1e67ffd, },
#                 overlays : {  }
#                 };
#             L.control.layers(
#                 layer_control_9ba5390a7937d21f5c68cff6d4990052.base_layers,
#                 layer_control_9ba5390a7937d21f5c68cff6d4990052.overlays,
#                 {position: &#x27;topright&#x27;,
#                  collapsed: true,
#                  autoZIndex: true
#                 }).addTo(map_cdfe16d731c8139875acf692e4124aa0);
#
#
#
#             var circle_marker_377302c88e4c8c45314e418a28cd5c9b = L.circleMarker(
#                 [11.11299012, 79.07532963],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 0.6181290857195471,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_cdfe16d731c8139875acf692e4124aa0);
#
#
#             var popup_775cba2c62986697ecead8d78e6478e5 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_8f2b66b38049811cc8420bb545a6b322 = $(`&lt;div id=&quot;html_8f2b66b38049811cc8420bb545a6b322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A.S Hospital&lt;/div&gt;`)[0];
#                 popup_775cba2c62986697ecead8d78e6478e5.setContent(html_8f2b66b38049811cc8420bb545a6b322);
#
#
#             circle_marker_377302c88e4c8c45314e418a28cd5c9b.bindPopup(popup_775cba2c62986697ecead8d78e6478e5)
#             ;
#
#
#
#
#             var circle_marker_df1d2bf379a86fe4084ec287fa7c9132 = L.circleMarker(
#                 [11.14104173, 79.0753868],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 0.6394438817788417,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_cdfe16d731c8139875acf692e4124aa0);
#
#
#             var popup_f4e682d454fac9a1288c6194686ce874 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_5682c064258dbeecd2d415b1149592e2 = $(`&lt;div id=&quot;html_5682c064258dbeecd2d415b1149592e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Hospital&lt;/div&gt;`)[0];
#                 popup_f4e682d454fac9a1288c6194686ce874.setContent(html_5682c064258dbeecd2d415b1149592e2);
#
#
#             circle_marker_df1d2bf379a86fe4084ec287fa7c9132.bindPopup(popup_f4e682d454fac9a1288c6194686ce874)
#             ;
#
#
#
#
#             var circle_marker_13c9502a387f043efa37ef587012b714 = L.circleMarker(
#                 [12.92102699, 80.08814903],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 0.852591842371789,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_cdfe16d731c8139875acf692e4124aa0);
#
#
#             var popup_6f6b2241d906572a661720d00020729d = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_77ed18176461ea964fbfc060a478ecaf = $(`&lt;div id=&quot;html_77ed18176461ea964fbfc060a478ecaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Annai Arul Hospital&lt;/div&gt;`)[0];
#                 popup_6f6b2241d906572a661720d00020729d.setContent(html_77ed18176461ea964fbfc060a478ecaf);
#
#
#             circle_marker_13c9502a387f043efa37ef587012b714.

# %% [markdown]
# ELBOW METHOD

# %%
sse = []
k_rng = range(25,100)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(dfn[['latitudes','longitudes']])
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.scatter(k_rng,sse,marker = '.' )
plt.annotate("X", (39, 2.3),color = 'r' )
plt.plot([40,40],[2,-0.5],color='green', linestyle='dashed', linewidth=2)

# %% [markdown]
# SILHOUETTE ANALYSIS

# %%
from sklearn.metrics import silhouette_score
range_n_clusters=[]
for i in range(25,100):
  range_n_clusters.append(i)

# %%
silhouette_avg = []
for num_clusters in range_n_clusters:
 
 # initialise kmeans
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(dfn[['latitudes','longitudes']])
 cluster_labels = kmeans.labels_
 
 # silhouette score
 silhouette_avg.append(silhouette_score(dfn[['latitudes','longitudes']], cluster_labels))
 if(silhouette_score(dfn[['latitudes','longitudes']], cluster_labels)>m1):
   m1=silhouette_score(dfn[['latitudes','longitudes']], cluster_labels)
   m2=cluster_labels
plt.plot(range_n_clusters,silhouette_avg,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Silhouette score') 
plt.title('Silhouette analysis For Optimal k')
plt.show()

# %%
km = KMeans(n_clusters=40)
y_predicted = km.fit_predict(dfn[['latitudes','longitudes']])

# %%
dfn['cluster']=y_predicted
dfn
# Out:
#      S.NO                                  Institution      District  \
# 0       1                                 A.S Hospital      Ariyalur
# 1       2                              Golden Hospital      Ariyalur
# 2       3                          Annai Arul Hospital  Chengalpattu
# 3       4         Chennai Emergency care Centre Pammal  Chengalpattu
# 4       5                           Dr. Rela Institute  Chengalpattu
# ..    ...                                          ...           ...
# 458   459           Trustlife Medical Centre, Panaiyur       Chennai
# 459   460             Vasantha Hospital, Thiruvottiyur       Chennai
# 460   461           Vijayakumar Hospital,Swamiyarmadam   Kanyakumari
# 461   462           Singhvi Health Center, Mint Street       Chennai
# 462   463  Hannah Joseph Hospital Pvt Ltd, Chinthamani       Madurai
#
#      COVID BEDS Total  COVID BEDS Occupied  latitudes  longitudes  cluster
# 0                  30                   29  11.112990   79.075330        4
# 1                  31                   30  11.141042   79.075387        4
# 2                  40                   40  12.921027   80.088149       25
# 3                  16                   16  12.973690   80.131118       25
# 4                 160                  160  12.956058   80.141067       25
# ..                ...                  ...        ...         ...      ...
# 458                20                   16  12.889022   80.246462       25
# 459                10                    9  13.173934   80.294032        1
# 460                22                   22   8.287601   77.269206        2
# 461                15                   15  13.093720   80.279634        1
# 462                75                   68   9.877585   78.136615        3
#
# [463 rows x 8 columns]

# %%
centroids=km.cluster_centers_.tolist()

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="http")
addr=[]
for i in range(len(centroids)):
  s=str(centroids[i][0])+ ','+str(centroids[i][1])
  location = geolocator.reverse(s)
  addr.append(location.address)

# %% [markdown]
# OPTIMAL LOCATION OF VACCINATION CENTERS ARE REPRESENTED BY GREEN MARKERS

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<center><b>'+cluster.getChildCount()+'</b></center>',
    className:'marker-cluster marker-cluster-large',
    iconSize:new L.Point(35, 35)
    });
}"""

# %%
m3 = folium.Map([11.41644605351662,78.73045144938763],tiles='OpenStreetMap',zoom_start=6)
locations = list(zip(dfn.latitudes, dfn.longitudes))
folium.plugins.MarkerCluster(locations=locations,                     
               popups=dfn['Institution'].tolist(),icon_create_function=icon_create_function).add_to(m3)
for i in range(len(centroids)):
    folium.Marker(centroids[i], popup = addr[i], icon=folium.Icon(color='green', icon_color='white', icon='plus')).add_to(m3)
display(m3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_989c508d59aed7abcf9cac7bf3a85d06 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_989c508d59aed7abcf9cac7bf3a85d06&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_989c508d59aed7abcf9cac7bf3a85d06 = L.map(
#         &#x27;map_989c508d59aed7abcf9cac7bf3a85d06&#x27;, {
#         center: [11.41644605351662, 78.73045144938763],
#         zoom: 6,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_f6a02c7868e52c821ab4b7f2db220c15 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_989c508d59aed7abcf9cac7bf3a85d06);
#
#             var marker_cluster_cf38c61602876e249c8f22a6bcc332e2 = L.markerClusterGroup({});
#             marker_cluster_cf38c61602876e249c8f22a6bcc332e2.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;center&gt;&lt;b&gt;&#x27;+cluster.getChildCount()+&#x27;&lt;/b&gt;&lt;/center&gt;&#x27;,
#     className:&#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize:new L.Point(35, 35)
#     });
# };
#             map_989c508d59aed7abcf9cac7bf3a85d06.addLayer(marker_cluster_cf38c61602876e249c8f22a6bcc332e2);
#
#
#         var marker_a0f4523a9d3f806c97c1a1bfac23fcb5 = L.marker(
#             [11.11299012, 79.07532963],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_cf38c61602876e249c8f22a6bcc332e2);
#
#
#             var popup_6b942b02fb91afd6db00e7b76335dcf9 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_09fe06613d3b6a6d7510416696f09fc1 = $(`&lt;div id=&quot;html_09fe06613d3b6a6d7510416696f09fc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A.S Hospital&lt;/div&gt;`)[0];
#                 popup_6b942b02fb91afd6db00e7b76335dcf9.setContent(html_09fe06613d3b6a6d7510416696f09fc1);
#
#
#             marker_a0f4523a9d3f806c97c1a1bfac23fcb5.bindPopup(popup_6b942b02fb91afd6db00e7b76335dcf9)
#             ;
#
#
#
#
#         var marker_a156495c42e86f49079398f42a0f0866 = L.marker(
#             [11.14104173, 79.0753868],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_cf38c61602876e249c8f22a6bcc332e2);
#
#
#             var popup_0549d2cf72f102e80a8aa8a69607af8e = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_b254083096cd268fc24f47cf02123ac0 = $(`&lt;div id=&quot;html_b254083096cd268fc24f47cf02123ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Hospital&lt;/div&gt;`)[0];
#                 popup_0549d2cf72f102e80a8aa8a69607af8e.setContent(html_b254083096cd268fc24f47cf02123ac0);
#
#
#             marker_a156495c42e86f49079398f42a0f0866.bindPopup(popup_0549d2cf72f102e80a8aa8a69607af8e)
#             ;
#
#
#
#
#         var marker_8e37dcc8ba8c397b65c9ce0d8e2ef42b = L.marker(
#             [12.92102699, 80.08814903],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_cf38c61602876e249c8f22a6bcc332e2);
#
#
#             var popup_32b492d0753a9b7de33f9aa6de319b8b = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_0293d388dade818ff30c27cdb0b04b69 = $(`&lt;div id=&quot;html_0293d388dade818ff30c27cdb0b04b69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Annai Arul Hospital&lt;/div&gt;`)[0];
#                 popup_32b492d0753a9b7de33f9aa6de319b8b.setContent(html_0293d388dade818ff30c27cdb0b04b69);
#
#
#             marker_8e37dcc8ba8c397b65c9ce0d8e2ef42b.bindPopup(popup_32b492d0753a9b7de33f9aa6de319b8b)
#             ;
#
#
#
#
#         var marker_f50e23a9c7ced85bd376c1a4305d350a = L.marker(
#             [12.97369039, 80.13111752],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(marker_cluster_cf38c61602876e249c8f22a6bcc332e2);
#
#
#             var popup_e653241fbc5ff73a1e12b886a5996dc0 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_9bc02e02fb5eeecc071a18fc5c424d73 = $(`&lt;div id=&quot;html_9bc02e02fb5eeecc071a18fc5c424d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chennai Emergency care Centre Pammal&lt;/div&gt;`)[0];
#                 popup_e653241fbc5ff73a1e12b886a5996dc0.setContent(html_9bc02e02fb5eeecc071a18fc5c424d73);
#
#
#             marker_f50e23a9c7ced85bd376c1a4305d350a.bindPopup(popup_e653241fbc5ff73a1e12b886a5996dc0)
#             ;
#
#
#
#
#         var marker_f1acc202dcec794d0dd4ab4638705949 = L.marker(

# %%
m2= folium.Map(
    location=[11.41644605351662, 78.73045144938763],
    zoom_start=9,tiles='OpenStreetMap')
folium.LayerControl().add_to(m2)
for row in dfn.iterrows():
    row=row[1]
    folium.CircleMarker(location=(row["latitudes"],
                                  row["longitudes"]),
                        radius= 2*row['COVID BEDS Occupied']/avg,
                        color="#FF0000",
                        popup=row['Institution'],
                        fill=True).add_to(m2)
for i in range(len(centroids)):
    folium.Marker(centroids[i], popup = addr[i], icon=folium.Icon(color='green', icon_color='white', icon='plus')).add_to(m2)
    
folium.LayerControl().add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_d7200f01d43361c8ddf504068a155ac2 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_d7200f01d43361c8ddf504068a155ac2&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_d7200f01d43361c8ddf504068a155ac2 = L.map(
#         &#x27;map_d7200f01d43361c8ddf504068a155ac2&#x27;, {
#         center: [11.41644605351662, 78.73045144938763],
#         zoom: 9,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_0476f480502e180e479c8bfed6147d23 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_d7200f01d43361c8ddf504068a155ac2);
#
#             var layer_control_fe2f8f1c0b8d1083eee65c6450c2d1ba = {
#                 base_layers : { &quot;openstreetmap&quot; : tile_layer_0476f480502e180e479c8bfed6147d23, },
#                 overlays : {  }
#                 };
#             L.control.layers(
#                 layer_control_fe2f8f1c0b8d1083eee65c6450c2d1ba.base_layers,
#                 layer_control_fe2f8f1c0b8d1083eee65c6450c2d1ba.overlays,
#                 {position: &#x27;topright&#x27;,
#                  collapsed: true,
#                  autoZIndex: true
#                 }).addTo(map_d7200f01d43361c8ddf504068a155ac2);
#
#
#
#             var circle_marker_ddfc41c5943fbb161d915ea33639317c = L.circleMarker(
#                 [11.11299012, 79.07532963],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 1.2362581714390941,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d7200f01d43361c8ddf504068a155ac2);
#
#
#             var popup_440098e2905f4dc66b1e7456d9e4f163 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_c355c8e7b2d501ca0a438e200a15172f = $(`&lt;div id=&quot;html_c355c8e7b2d501ca0a438e200a15172f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A.S Hospital&lt;/div&gt;`)[0];
#                 popup_440098e2905f4dc66b1e7456d9e4f163.setContent(html_c355c8e7b2d501ca0a438e200a15172f);
#
#
#             circle_marker_ddfc41c5943fbb161d915ea33639317c.bindPopup(popup_440098e2905f4dc66b1e7456d9e4f163)
#             ;
#
#
#
#
#             var circle_marker_ba363f3f910b1de8f1debf99da2c4e76 = L.circleMarker(
#                 [11.14104173, 79.0753868],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 1.2788877635576834,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d7200f01d43361c8ddf504068a155ac2);
#
#
#             var popup_47774334a133e3f9be944c65b38caa84 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_d0eadf9d9bee8cf32c4dbb891fa325b6 = $(`&lt;div id=&quot;html_d0eadf9d9bee8cf32c4dbb891fa325b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Hospital&lt;/div&gt;`)[0];
#                 popup_47774334a133e3f9be944c65b38caa84.setContent(html_d0eadf9d9bee8cf32c4dbb891fa325b6);
#
#
#             circle_marker_ba363f3f910b1de8f1debf99da2c4e76.bindPopup(popup_47774334a133e3f9be944c65b38caa84)
#             ;
#
#
#
#
#             var circle_marker_2925e9ad08d6be9ef2d15c19f4dc1833 = L.circleMarker(
#                 [12.92102699, 80.08814903],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#FF0000&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#FF0000&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 1.705183684743578,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_d7200f01d43361c8ddf504068a155ac2);
#
#
#             var popup_c2255439b477085e6c55932bdf973010 = L.popup({maxWidth: &#x27;100%&#x27;
#
#             });
#
#
#                 var html_5666db43f74fb46302e30a83546664a2 = $(`&lt;div id=&quot;html_5666db43f74fb46302e30a83546664a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Annai Arul Hospital&lt;/div&gt;`)[0];
#                 popup_c2255439b477085e6c55932bdf973010.setContent(html_5666db43f74fb46302e30a83546664a2);
#
#
#             circle_marker_2925e9ad08d6be9ef2d15c19f4dc1833.bi
